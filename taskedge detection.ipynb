# %%
import cv2

# %%
#opencv functions
img = cv2.imread('2.jpg')
 # Canny edge detection.
edges = cv2.Canny(img, 100, 150)
cv2.imshow('edge detection', edges)
cv2.waitKey(0)
# Out:
# QObject::moveToThread: Current thread (0x562b1804fe70) is not the object's thread (0x562b18331340).
# Cannot move to target thread (0x562b1804fe70)
#
# QObject::moveToThread: Current thread (0x562b1804fe70) is not the object's thread (0x562b18331340).
# Cannot move to target thread (0x562b1804fe70)
#
# QObject::moveToThread: Current thread (0x562b1804fe70) is not the object's thread (0x562b18331340).
# Cannot move to target thread (0x562b1804fe70)
#
# QObject::moveToThread: Current thread (0x562b1804fe70) is not the object's thread (0x562b18331340).
# Cannot move to target thread (0x562b1804fe70)
#
# QObject::moveToThread: Current thread (0x562b1804fe70) is not the object's thread (0x562b18331340).
# Cannot move to target thread (0x562b1804fe70)
#
# QObject::moveToThread: Current thread (0x562b1804fe70) is not the object's thread (0x562b18331340).
# Cannot move to target thread (0x562b1804fe70)
#
# ...
